# %%
import pandas as pd
import os
from openpyxl import load_workbook
from openpyxl.styles import Font, PatternFill, Alignment, NamedStyle
from openpyxl.utils import get_column_letter

# Test the function
Served_Invoice = "Served Invoice"

# Define paths
export_path = r"C:\Users\User\Downloads\COB DATA\2025\11.November\Customer Returns\Export"
os.makedirs(export_path, exist_ok=True)

# Define import path
import_path = r"C:\Users\User\Downloads\COB DATA\2025\11.November\Customer Returns\Data"

# Define import filenames
# im_filename_inv = "01.xlsx"

# Define full import paths
# Served_Invoice_path = os.path.join(export_path, Served_Invoice)

Served_Invoice_file = "Cuctomer Returns 2025.xlsx"
# Served_Invoice_file_2025 = "Served_Invoice 2025.xlsx"
Served_Invoice_path = os.path.join(export_path, Served_Invoice_file)
# Served_Invoice_path_2025 = os.path.join(export_path, Served_Invoice_file_2025)

# %%
full_im_path_inv = os.path.join(import_path, "01.xlsx")

df1 = pd.read_excel(full_im_path_inv)

# dfc = df1[['Invoice Date', 'Sold To Customer Number', 'Sold To Customer Name',
#            'Product Code', 'Product/Item Description',
#            'Product UOM', 'Quantity', 'Invoice Item Type']]
# inv = dfc[dfc['Invoice Item Type'] != 'ITM_SALES_TAX']

inv = df1[['Customer Return Date', 'Sold To Customer Number', 'Sold To Customer Name',
           'Return/QC Reason Code', 'Product Code', 'Product Description',
           'UOM', 'Return/ QC Quantity','Customer Return Type']]
inv = inv[inv['Customer Return Type'] != 'QC_RETURNS']

# filter the dataframe step by step and use .isin for multiple product codes
inv_f1 = inv.loc[inv['Sold To Customer Number'] == 'E3123A0055']
# inv_f = inv_f.loc[inv_f['Product Code'].isin(['2403', '2427'])]

# use .loc for inplace-safe assignments
inv_f1.loc[:, 'Return/ QC Quantity'] = inv_f1['Return/ QC Quantity'].fillna(0)
inv_f1.loc[:, 'Product Code'] = inv_f1['Product Code'].astype(str)
inv_f1 = inv_f1.drop('Customer Return Type', axis=1)

i = 1
print(f"DONE : {i} / 10")

full_im_path_inv = os.path.join(import_path, "02.xlsx")

df1 = pd.read_excel(full_im_path_inv)

# dfc = df1[['Invoice Date', 'Sold To Customer Number', 'Sold To Customer Name',
#            'Product Code', 'Product/Item Description',
#            'Product UOM', 'Quantity', 'Invoice Item Type']]
# inv = dfc[dfc['Invoice Item Type'] != 'ITM_SALES_TAX']

inv = df1[['Customer Return Date', 'Sold To Customer Number', 'Sold To Customer Name',
           'Return/QC Reason Code', 'Product Code', 'Product Description',
           'UOM', 'Return/ QC Quantity','Customer Return Type']]
inv = inv[inv['Customer Return Type'] != 'QC_RETURNS']

# filter the dataframe step by step and use .isin for multiple product codes
inv_f2 = inv.loc[inv['Sold To Customer Number'] == 'E3123A0055']
# inv_f = inv_f.loc[inv_f['Product Code'].isin(['2403', '2427'])]

# use .loc for inplace-safe assignments
inv_f2.loc[:, 'Return/ QC Quantity'] = inv_f2['Return/ QC Quantity'].fillna(0)
inv_f2.loc[:, 'Product Code'] = inv_f2['Product Code'].astype(str)
inv_f2 = inv_f2.drop('Customer Return Type', axis=1)

i = i+1
print(f"DONE : {i} / 10")

combine_01 = pd.concat([inv_f1, inv_f2], ignore_index=True)
o = 1
print(f"Export : {o} / 9")
combine_01.to_excel(Served_Invoice_path, index=False)
##############################

full_im_path_inv = os.path.join(import_path, "03.xlsx")

df1 = pd.read_excel(full_im_path_inv)

# dfc = df1[['Invoice Date', 'Sold To Customer Number', 'Sold To Customer Name',
#            'Product Code', 'Product/Item Description',
#            'Product UOM', 'Quantity', 'Invoice Item Type']]
# inv = dfc[dfc['Invoice Item Type'] != 'ITM_SALES_TAX']

inv = df1[['Customer Return Date', 'Sold To Customer Number', 'Sold To Customer Name',
           'Return/QC Reason Code', 'Product Code', 'Product Description',
           'UOM', 'Return/ QC Quantity','Customer Return Type']]
inv = inv[inv['Customer Return Type'] != 'QC_RETURNS']

# filter the dataframe step by step and use .isin for multiple product codes
inv_f3 = inv.loc[inv['Sold To Customer Number'] == 'E3123A0055']
# inv_f = inv_f.loc[inv_f['Product Code'].isin(['2403', '2427'])]

# use .loc for inplace-safe assignments
inv_f3.loc[:, 'Return/ QC Quantity'] = inv_f3['Return/ QC Quantity'].fillna(0)
inv_f3.loc[:, 'Product Code'] = inv_f3['Product Code'].astype(str)
inv_f3 = inv_f3.drop('Customer Return Type', axis=1)

i = i+1
print(f"DONE : {i} / 10")

combine_02 = pd.concat([inv_f1, inv_f2, inv_f3], ignore_index=True)
o = o+1
print(f"Export : {o} / 9")
combine_02.to_excel(Served_Invoice_path, index=False)
##############################

full_im_path_inv = os.path.join(import_path, "04.xlsx")

df1 = pd.read_excel(full_im_path_inv)

# dfc = df1[['Invoice Date', 'Sold To Customer Number', 'Sold To Customer Name',
#            'Product Code', 'Product/Item Description',
#            'Product UOM', 'Quantity', 'Invoice Item Type']]
# inv = dfc[dfc['Invoice Item Type'] != 'ITM_SALES_TAX']

inv = df1[['Customer Return Date', 'Sold To Customer Number', 'Sold To Customer Name',
           'Return/QC Reason Code', 'Product Code', 'Product Description',
           'UOM', 'Return/ QC Quantity','Customer Return Type']]
inv = inv[inv['Customer Return Type'] != 'QC_RETURNS']

# filter the dataframe step by step and use .isin for multiple product codes
inv_f4 = inv.loc[inv['Sold To Customer Number'] == 'E3123A0055']
# inv_f = inv_f.loc[inv_f['Product Code'].isin(['2403', '2427'])]

# use .loc for inplace-safe assignments
inv_f4.loc[:, 'Return/ QC Quantity'] = inv_f4['Return/ QC Quantity'].fillna(0)
inv_f4.loc[:, 'Product Code'] = inv_f4['Product Code'].astype(str)
inv_f4 = inv_f4.drop('Customer Return Type', axis=1)

i = i+1
print(f"DONE : {i} / 10")

combine_03 = pd.concat([inv_f1, inv_f2, inv_f3, inv_f4], ignore_index=True)
o = o+1
print(f"Export  : {o} / 9")
combine_03.to_excel(Served_Invoice_path, index=False)
##############################

full_im_path_inv = os.path.join(import_path, "05.xlsx")

df1 = pd.read_excel(full_im_path_inv)

# dfc = df1[['Invoice Date', 'Sold To Customer Number', 'Sold To Customer Name',
#            'Product Code', 'Product/Item Description',
#            'Product UOM', 'Quantity', 'Invoice Item Type']]
# inv = dfc[dfc['Invoice Item Type'] != 'ITM_SALES_TAX']

inv = df1[['Customer Return Date', 'Sold To Customer Number', 'Sold To Customer Name',
           'Return/QC Reason Code', 'Product Code', 'Product Description',
           'UOM', 'Return/ QC Quantity','Customer Return Type']]
inv = inv[inv['Customer Return Type'] != 'QC_RETURNS']

# filter the dataframe step by step and use .isin for multiple product codes
inv_f5 = inv.loc[inv['Sold To Customer Number'] == 'E3123A0055']
# inv_f = inv_f.loc[inv_f['Product Code'].isin(['2403', '2427'])]

# use .loc for inplace-safe assignments
inv_f5.loc[:, 'Return/ QC Quantity'] = inv_f5['Return/ QC Quantity'].fillna(0)
inv_f5.loc[:, 'Product Code'] = inv_f5['Product Code'].astype(str)
inv_f5 = inv_f5.drop('Customer Return Type', axis=1)

i = i+1
print(f"DONE : {i} / 10")

combine_04 = pd.concat([inv_f1, inv_f2, inv_f3, inv_f4, inv_f5], ignore_index=True)
o = o+1
print(f"Export : {o} / 9")
combine_04.to_excel(Served_Invoice_path, index=False)  
##############################

full_im_path_inv = os.path.join(import_path, "06.xlsx")

df1 = pd.read_excel(full_im_path_inv)

# dfc = df1[['Invoice Date', 'Sold To Customer Number', 'Sold To Customer Name',
#            'Product Code', 'Product/Item Description',
#            'Product UOM', 'Quantity', 'Invoice Item Type']]
# inv = dfc[dfc['Invoice Item Type'] != 'ITM_SALES_TAX']

inv = df1[['Customer Return Date', 'Sold To Customer Number', 'Sold To Customer Name',
           'Return/QC Reason Code', 'Product Code', 'Product Description',
           'UOM', 'Return/ QC Quantity','Customer Return Type']]
inv = inv[inv['Customer Return Type'] != 'QC_RETURNS']

# filter the dataframe step by step and use .isin for multiple product codes
inv_f6 = inv.loc[inv['Sold To Customer Number'] == 'E3123A0055']
# inv_f = inv_f.loc[inv_f['Product Code'].isin(['2403', '2427'])]

# use .loc for inplace-safe assignments
inv_f6.loc[:, 'Return/ QC Quantity'] = inv_f6['Return/ QC Quantity'].fillna(0)
inv_f6.loc[:, 'Product Code'] = inv_f6['Product Code'].astype(str)
inv_f6 = inv_f6.drop('Customer Return Type', axis=1)

i = i+1
print(f"DONE : {i} / 10")

combine_05 = pd.concat([inv_f1, inv_f2, inv_f3, inv_f4, inv_f5, inv_f6], ignore_index=True)
o = o+1
print(f"Export : {o} / 9")
combine_05.to_excel(Served_Invoice_path, index=False)
##############################

full_im_path_inv = os.path.join(import_path, "07.xlsx")

df1 = pd.read_excel(full_im_path_inv)

# dfc = df1[['Invoice Date', 'Sold To Customer Number', 'Sold To Customer Name',
#            'Product Code', 'Product/Item Description',
#            'Product UOM', 'Quantity', 'Invoice Item Type']]
# inv = dfc[dfc['Invoice Item Type'] != 'ITM_SALES_TAX']

inv = df1[['Customer Return Date', 'Sold To Customer Number', 'Sold To Customer Name',
           'Return/QC Reason Code', 'Product Code', 'Product Description',
           'UOM', 'Return/ QC Quantity','Customer Return Type']]
inv = inv[inv['Customer Return Type'] != 'QC_RETURNS']

# filter the dataframe step by step and use .isin for multiple product codes
inv_f7 = inv.loc[inv['Sold To Customer Number'] == 'E3123A0055']
# inv_f = inv_f.loc[inv_f['Product Code'].isin(['2403', '2427'])]

# use .loc for inplace-safe assignments
inv_f7.loc[:, 'Return/ QC Quantity'] = inv_f7['Return/ QC Quantity'].fillna(0)
inv_f7.loc[:, 'Product Code'] = inv_f7['Product Code'].astype(str)
inv_f7 = inv_f7.drop('Customer Return Type', axis=1)

i = i+1
print(f"DONE : {i} / 10")

combine_06 = pd.concat([inv_f1, inv_f2, inv_f3, inv_f4, inv_f5, inv_f6, inv_f7], ignore_index=True)
o = o+1
print(f"Export : {o} / 9")
combine_06.to_excel(Served_Invoice_path, index=False)
###############################

full_im_path_inv = os.path.join(import_path, "08.xlsx")

df1 = pd.read_excel(full_im_path_inv)

# dfc = df1[['Invoice Date', 'Sold To Customer Number', 'Sold To Customer Name',
#            'Product Code', 'Product/Item Description',
#            'Product UOM', 'Quantity', 'Invoice Item Type']]
# inv = dfc[dfc['Invoice Item Type'] != 'ITM_SALES_TAX']

inv = df1[['Customer Return Date', 'Sold To Customer Number', 'Sold To Customer Name',
           'Return/QC Reason Code', 'Product Code', 'Product Description',
           'UOM', 'Return/ QC Quantity','Customer Return Type']]
inv = inv[inv['Customer Return Type'] != 'QC_RETURNS']

# filter the dataframe step by step and use .isin for multiple product codes
inv_f8 = inv.loc[inv['Sold To Customer Number'] == 'E3123A0055']
# inv_f = inv_f.loc[inv_f['Product Code'].isin(['2403', '2427'])]

# use .loc for inplace-safe assignments
inv_f8.loc[:, 'Return/ QC Quantity'] = inv_f8['Return/ QC Quantity'].fillna(0)
inv_f8.loc[:, 'Product Code'] = inv_f8['Product Code'].astype(str)
inv_f8 = inv_f8.drop('Customer Return Type', axis=1)

i = i+1
print(f"DONE : {i} / 10")

combine_07 = pd.concat([inv_f1, inv_f2, inv_f3, inv_f4, inv_f5, inv_f6, inv_f7, inv_f8], ignore_index=True)
o = o+1
print(f"Export : {o} / 9")
combine_07.to_excel(Served_Invoice_path, index=False)
##############################

full_im_path_inv = os.path.join(import_path, "09.xlsx")

df1 = pd.read_excel(full_im_path_inv)

# dfc = df1[['Invoice Date', 'Sold To Customer Number', 'Sold To Customer Name',
#            'Product Code', 'Product/Item Description',
#            'Product UOM', 'Quantity', 'Invoice Item Type']]
# inv = dfc[dfc['Invoice Item Type'] != 'ITM_SALES_TAX']

inv = df1[['Customer Return Date', 'Sold To Customer Number', 'Sold To Customer Name',
           'Return/QC Reason Code', 'Product Code', 'Product Description',
           'UOM', 'Return/ QC Quantity','Customer Return Type']]
inv = inv[inv['Customer Return Type'] != 'QC_RETURNS']

# filter the dataframe step by step and use .isin for multiple product codes
inv_f9 = inv.loc[inv['Sold To Customer Number'] == 'E3123A0055']
# inv_f = inv_f.loc[inv_f['Product Code'].isin(['2403', '2427'])]

# use .loc for inplace-safe assignments
inv_f9.loc[:, 'Return/ QC Quantity'] = inv_f9['Return/ QC Quantity'].fillna(0)
inv_f9.loc[:, 'Product Code'] = inv_f9['Product Code'].astype(str)
inv_f9 = inv_f9.drop('Customer Return Type', axis=1)

i = i+1
print(f"DONE : {i} / 10")

combine_08 = pd.concat([inv_f1, inv_f2, inv_f3, inv_f4, inv_f5, inv_f6, inv_f7, inv_f8, inv_f9], ignore_index=True)
o = o+1
print(f"Export : {o} / 9")
combine_08.to_excel(Served_Invoice_path, index=False)
##############################

full_im_path_inv = os.path.join(import_path, "09.xlsx")

df1 = pd.read_excel(full_im_path_inv)

# dfc = df1[['Invoice Date', 'Sold To Customer Number', 'Sold To Customer Name',
#            'Product Code', 'Product/Item Description',
#            'Product UOM', 'Quantity', 'Invoice Item Type']]
# inv = dfc[dfc['Invoice Item Type'] != 'ITM_SALES_TAX']

inv = df1[['Customer Return Date', 'Sold To Customer Number', 'Sold To Customer Name',
           'Return/QC Reason Code', 'Product Code', 'Product Description',
           'UOM', 'Return/ QC Quantity','Customer Return Type']]
inv = inv[inv['Customer Return Type'] != 'QC_RETURNS']

# filter the dataframe step by step and use .isin for multiple product codes
inv_f10 = inv.loc[inv['Sold To Customer Number'] == 'E3123A0055']
# inv_f = inv_f.loc[inv_f['Product Code'].isin(['2403', '2427'])]

# use .loc for inplace-safe assignments
inv_f10.loc[:, 'Return/ QC Quantity'] = inv_f10['Return/ QC Quantity'].fillna(0)
inv_f10.loc[:, 'Product Code'] = inv_f10['Product Code'].astype(str)
inv_f10 = inv_f10.drop('Customer Return Type', axis=1)

i = i+1
print(f"DONE : {i} / 10")

combine_08 = pd.concat([inv_f1, inv_f2, inv_f3, inv_f4, inv_f5, inv_f6, inv_f7, inv_f8, inv_f9, inv_f10], ignore_index=True)
o = o+1
print(f"Export : {o} / 9")
combine_08.to_excel(Served_Invoice_path, index=False)
##############################
# Out:
# c:\Python313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# DONE : 1 / 10
# c:\Python313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# DONE : 2 / 10
# Export : 1 / 9
# c:\Python313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# DONE : 3 / 10
# Export : 2 / 9
# c:\Python313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# DONE : 4 / 10
# Export  : 3 / 9
# ...

# %%
# full_im_path_inv = os.path.join(import_path, "10.xlsx")

# df1 = pd.read_excel(full_im_path_inv)

# dfc = df1[['Invoice Date', 'Sold To Customer Number', 'Sold To Customer Name',
#            'Product Code', 'Product/Item Description',
#            'Product UOM', 'Quantity', 'Invoice Item Type']]
# inv = dfc[dfc['Invoice Item Type'] != 'ITM_SALES_TAX']

# # filter the dataframe step by step and use .isin for multiple product codes
# inv_f = inv.loc[inv['Sold To Customer Number'] == 'E3123A0055']
# # inv_f = inv_f.loc[inv_f['Product Code'].isin(['2403', '2427'])]

# # use .loc for inplace-safe assignments
# inv_f.loc[:, 'Quantity'] = inv_f['Quantity'].fillna(0)
# inv_f.loc[:, 'Product Code'] = inv_f['Product Code'].astype(str)
# inv_f10 = inv_f.drop('Invoice Item Type', axis=1)

# i = i+1
# print(f"DONE : {i} / 19")

# full_im_path_inv = os.path.join(import_path, "11.xlsx")

# df1 = pd.read_excel(full_im_path_inv)

# dfc = df1[['Invoice Date', 'Sold To Customer Number', 'Sold To Customer Name',
#            'Product Code', 'Product/Item Description',
#            'Product UOM', 'Quantity', 'Invoice Item Type']]
# inv = dfc[dfc['Invoice Item Type'] != 'ITM_SALES_TAX']

# # filter the dataframe step by step and use .isin for multiple product codes
# inv_f = inv.loc[inv['Sold To Customer Number'] == 'E3123A0055']
# # inv_f = inv_f.loc[inv_f['Product Code'].isin(['2403', '2427'])]

# # use .loc for inplace-safe assignments
# inv_f.loc[:, 'Quantity'] = inv_f['Quantity'].fillna(0)
# inv_f.loc[:, 'Product Code'] = inv_f['Product Code'].astype(str)
# inv_f11 = inv_f.drop('Invoice Item Type', axis=1)

# i = i+1
# print(f"DONE : {i} / 19")

# combine_10 = pd.concat([inv_f10, inv_f11], ignore_index=True)
# o = o+1
# print(f"Export : {o} / 17")
# combine_10.to_excel(Served_Invoice_path_2025, index=False)
# ##############################

# full_im_path_inv = os.path.join(import_path, "12.xlsx")

# df1 = pd.read_excel(full_im_path_inv)

# dfc = df1[['Invoice Date', 'Sold To Customer Number', 'Sold To Customer Name',
#            'Product Code', 'Product/Item Description',
#            'Product UOM', 'Quantity', 'Invoice Item Type']]
# inv = dfc[dfc['Invoice Item Type'] != 'ITM_SALES_TAX']

# # filter the dataframe step by step and use .isin for multiple product codes
# inv_f = inv.loc[inv['Sold To Customer Number'] == 'E3123A0055']
# # inv_f = inv_f.loc[inv_f['Product Code'].isin(['2403', '2427'])]

# # use .loc for inplace-safe assignments
# inv_f.loc[:, 'Quantity'] = inv_f['Quantity'].fillna(0)
# inv_f.loc[:, 'Product Code'] = inv_f['Product Code'].astype(str)
# inv_f12 = inv_f.drop('Invoice Item Type', axis=1)

# i = i+1
# print(f"DONE : {i} / 19")

# combine_11 = pd.concat([inv_f10, inv_f11, inv_f12], ignore_index=True)
# o = o+1
# print(f"Export : {o} / 17")
# combine_11.to_excel(Served_Invoice_path_2025, index=False)
# ##############################

# full_im_path_inv = os.path.join(import_path, "13.xlsx")

# df1 = pd.read_excel(full_im_path_inv)

# dfc = df1[['Invoice Date', 'Sold To Customer Number', 'Sold To Customer Name',
#            'Product Code', 'Product/Item Description',
#            'Product UOM', 'Quantity', 'Invoice Item Type']]
# inv = dfc[dfc['Invoice Item Type'] != 'ITM_SALES_TAX']

# # filter the dataframe step by step and use .isin for multiple product codes
# inv_f = inv.loc[inv['Sold To Customer Number'] == 'E3123A0055']
# # inv_f = inv_f.loc[inv_f['Product Code'].isin(['2403', '2427'])]

# # use .loc for inplace-safe assignments
# inv_f.loc[:, 'Quantity'] = inv_f['Quantity'].fillna(0)
# inv_f.loc[:, 'Product Code'] = inv_f['Product Code'].astype(str)
# inv_f13 = inv_f.drop('Invoice Item Type', axis=1)

# i = i+1
# print(f"DONE : {i} / 19")

# combine_12 = pd.concat([inv_f10, inv_f11, inv_f12, inv_f13], ignore_index=True)
# o = o+1
# print(f"Export : {o} / 17")
# combine_12.to_excel(Served_Invoice_path_2025, index=False)
# ##############################

# full_im_path_inv = os.path.join(import_path, "14.xlsx")

# df1 = pd.read_excel(full_im_path_inv)

# dfc = df1[['Invoice Date', 'Sold To Customer Number', 'Sold To Customer Name',
#            'Product Code', 'Product/Item Description',
#            'Product UOM', 'Quantity', 'Invoice Item Type']]
# inv = dfc[dfc['Invoice Item Type'] != 'ITM_SALES_TAX']

# # filter the dataframe step by step and use .isin for multiple product codes
# inv_f = inv.loc[inv['Sold To Customer Number'] == 'E3123A0055']
# # inv_f = inv_f.loc[inv_f['Product Code'].isin(['2403', '2427'])]

# # use .loc for inplace-safe assignments
# inv_f.loc[:, 'Quantity'] = inv_f['Quantity'].fillna(0)
# inv_f.loc[:, 'Product Code'] = inv_f['Product Code'].astype(str)
# inv_f14 = inv_f.drop('Invoice Item Type', axis=1)

# i = i+1
# print(f"DONE : {i} / 19")

# combine_13 = pd.concat([inv_f10, inv_f11, inv_f12, inv_f13, inv_f14], ignore_index=True)
# o = o+1
# print(f"Export : {o} / 17")
# combine_13.to_excel(Served_Invoice_path_2025, index=False)
# ##############################

# full_im_path_inv = os.path.join(import_path, "15.xlsx")

# df1 = pd.read_excel(full_im_path_inv)

# dfc = df1[['Invoice Date', 'Sold To Customer Number', 'Sold To Customer Name',
#            'Product Code', 'Product/Item Description',
#            'Product UOM', 'Quantity', 'Invoice Item Type']]
# inv = dfc[dfc['Invoice Item Type'] != 'ITM_SALES_TAX']

# # filter the dataframe step by step and use .isin for multiple product codes
# inv_f = inv.loc[inv['Sold To Customer Number'] == 'E3123A0055']
# # inv_f = inv_f.loc[inv_f['Product Code'].isin(['2403', '2427'])]

# # use .loc for inplace-safe assignments
# inv_f.loc[:, 'Quantity'] = inv_f['Quantity'].fillna(0)
# inv_f.loc[:, 'Product Code'] = inv_f['Product Code'].astype(str)
# inv_f15 = inv_f.drop('Invoice Item Type', axis=1)

# i = i+1
# print(f"DONE : {i} / 19")

# combine_14 = pd.concat([inv_f10, inv_f11, inv_f12, inv_f13, inv_f14, inv_f15], ignore_index=True)
# o = o+1
# print(f"Export : {o} / 17")
# combine_14.to_excel(Served_Invoice_path_2025, index=False)
# ##############################

# full_im_path_inv = os.path.join(import_path, "16.xlsx")

# df1 = pd.read_excel(full_im_path_inv)

# dfc = df1[['Invoice Date', 'Sold To Customer Number', 'Sold To Customer Name',
#            'Product Code', 'Product/Item Description',
#            'Product UOM', 'Quantity', 'Invoice Item Type']]
# inv = dfc[dfc['Invoice Item Type'] != 'ITM_SALES_TAX']

# # filter the dataframe step by step and use .isin for multiple product codes
# inv_f = inv.loc[inv['Sold To Customer Number'] == 'E3123A0055']
# # inv_f = inv_f.loc[inv_f['Product Code'].isin(['2403', '2427'])]

# # use .loc for inplace-safe assignments
# inv_f.loc[:, 'Quantity'] = inv_f['Quantity'].fillna(0)
# inv_f.loc[:, 'Product Code'] = inv_f['Product Code'].astype(str)
# inv_f16 = inv_f.drop('Invoice Item Type', axis=1)

# i = i+1
# print(f"DONE : {i} / 19")

# combine_15 = pd.concat([inv_f10, inv_f11, inv_f12, inv_f13, inv_f14, inv_f15, inv_f16], ignore_index=True)
# o = o+1
# print(f"Export : {o} / 17")
# combine_15.to_excel(Served_Invoice_path_2025, index=False)
# ##############################

# full_im_path_inv = os.path.join(import_path, "17.xlsx")

# df1 = pd.read_excel(full_im_path_inv)

# dfc = df1[['Invoice Date', 'Sold To Customer Number', 'Sold To Customer Name',
#            'Product Code', 'Product/Item Description',
#            'Product UOM', 'Quantity', 'Invoice Item Type']]
# inv = dfc[dfc['Invoice Item Type'] != 'ITM_SALES_TAX']

# # filter the dataframe step by step and use .isin for multiple product codes
# inv_f = inv.loc[inv['Sold To Customer Number'] == 'E3123A0055']
# # inv_f = inv_f.loc[inv_f['Product Code'].isin(['2403', '2427'])]

# # use .loc for inplace-safe assignments
# inv_f.loc[:, 'Quantity'] = inv_f['Quantity'].fillna(0)
# inv_f.loc[:, 'Product Code'] = inv_f['Product Code'].astype(str)
# inv_f17 = inv_f.drop('Invoice Item Type', axis=1)

# i = i+1
# print(f"DONE : {i} / 19")

# combine_16 = pd.concat([inv_f10, inv_f11, inv_f12, inv_f13, inv_f14, inv_f15, inv_f16, inv_f17], ignore_index=True)
# o = o+1
# print(f"Export : {o} / 17")
# combine_16.to_excel(Served_Invoice_path_2025, index=False)
# ##############################

# full_im_path_inv = os.path.join(import_path, "18.xlsx")

# df1 = pd.read_excel(full_im_path_inv)

# dfc = df1[['Invoice Date', 'Sold To Customer Number', 'Sold To Customer Name',
#            'Product Code', 'Product/Item Description',
#            'Product UOM', 'Quantity', 'Invoice Item Type']]
# inv = dfc[dfc['Invoice Item Type'] != 'ITM_SALES_TAX']

# # filter the dataframe step by step and use .isin for multiple product codes
# inv_f = inv.loc[inv['Sold To Customer Number'] == 'E3123A0055']
# # inv_f = inv_f.loc[inv_f['Product Code'].isin(['2403', '2427'])]

# # use .loc for inplace-safe assignments
# inv_f.loc[:, 'Quantity'] = inv_f['Quantity'].fillna(0)
# inv_f.loc[:, 'Product Code'] = inv_f['Product Code'].astype(str)
# inv_f18 = inv_f.drop('Invoice Item Type', axis=1)

# i = i+1
# print(f"DONE : {i} / 19")

# combine_17 = pd.concat([inv_f10, inv_f11, inv_f12, inv_f13, inv_f14, inv_f15, inv_f16, inv_f17, inv_f18], ignore_index=True)
# o = o+1
# print(f"Export : {o} / 17")
# combine_17.to_excel(Served_Invoice_path_2025, index=False)
# ##############################

# full_im_path_inv = os.path.join(import_path, "19.xlsx")

# df1 = pd.read_excel(full_im_path_inv)

# dfc = df1[['Invoice Date', 'Sold To Customer Number', 'Sold To Customer Name',
#            'Product Code', 'Product/Item Description',
#            'Product UOM', 'Quantity', 'Invoice Item Type']]
# inv = dfc[dfc['Invoice Item Type'] != 'ITM_SALES_TAX']

# # filter the dataframe step by step and use .isin for multiple product codes
# inv_f = inv.loc[inv['Sold To Customer Number'] == 'E3123A0055']
# # inv_f = inv_f.loc[inv_f['Product Code'].isin(['2403', '2427'])]

# # use .loc for inplace-safe assignments
# inv_f.loc[:, 'Quantity'] = inv_f['Quantity'].fillna(0)
# inv_f.loc[:, 'Product Code'] = inv_f['Product Code'].astype(str)
# inv_f19 = inv_f.drop('Invoice Item Type', axis=1)

# i = i+1
# print(f"DONE : {i} / 19")

# combine_18 = pd.concat([inv_f10, inv_f11, inv_f12, inv_f13, inv_f14, inv_f15, inv_f16, inv_f17, inv_f18, inv_f19], ignore_index=True)
# o = o+1
# print(f"Export : {o} / 17")
# combine_18.to_excel(Served_Invoice_path_2025, index=False)

# %%
combined = combine_18

# ensure output path includes filename
Served_Invoice_file = "Served_Invoice.xlsx"
Served_Invoice_path = os.path.join(export_path, Served_Invoice_file)

combined.to_excel(Served_Invoice_path, index=False)
# ...existing code...
