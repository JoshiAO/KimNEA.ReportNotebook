# %%
import pandas as pd
import os
from openpyxl import load_workbook
from openpyxl.styles import Font, PatternFill, Alignment, NamedStyle
from openpyxl.utils import get_column_letter

# Test the function
Served_Invoice = "Served Invoice"

# Define paths
export_path = r"C:\Users\User\Downloads\COB DATA\2025\12.December\12.30.25"
os.makedirs(export_path, exist_ok=True)

# Define import path
imp_Erika = r"C:\Users\User\OneDrive\Kimberlin Enterprises\Shared Public Folder\OFFICE FILE\SALES ORDER STATUS\ERIKA\WRONG C.I. MONITORING\CY2025 WRONG C.I. MONITORING DECEMBER.xlsx"
imp_Kath = r"C:\Users\User\OneDrive\Kimberlin Enterprises\Shared Public Folder\OFFICE FILE\SALES ORDER STATUS\KATH\WRONG C.I. MONITORING\CY2025 WRONG C.I. MONITORING DECEMBER.xlsx"
imp_Mae = r"C:\Users\User\OneDrive\Kimberlin Enterprises\Shared Public Folder\OFFICE FILE\SALES ORDER STATUS\MARRY MAE\WRONG C.I. MONITORING\CY2025 WRONG C.I. MONITORING DECEMBER.xlsx"
imp_Shaine = r"C:\Users\User\OneDrive\Kimberlin Enterprises\Shared Public Folder\OFFICE FILE\SALES ORDER STATUS\SHAINE\WRONG C.I. MONITORING\CY2025 WRONG C.I. MONITORING DECEMBER.xlsx"

# %%
# Load data from Excel files
df_Erika = pd.read_excel(imp_Erika, skiprows=4)
df_Erika = df_Erika.drop(index=0)  # Drop the first row
df_Kath = pd.read_excel(imp_Kath, skiprows=4)
df_Kath = df_Kath.drop(index=0)  # Drop the first row
df_Mae = pd.read_excel(imp_Mae, skiprows=4)
df_Mae = df_Mae.drop(index=0)  # Drop the first row
df_Shaine = pd.read_excel(imp_Shaine, skiprows=4)
df_Shaine = df_Shaine.drop(index=0)  # Drop the first row

# Combine dataframes
df_combined = pd.concat([df_Erika, df_Kath, df_Mae, df_Shaine], ignore_index=True)

df_combined.head()

# Export combined dataframe to Excel
export_file = os.path.join(export_path, "COMBINED.xlsx")
df_combined.to_excel(export_file, index=False)

# %%
df_Mae_disp = df_Mae.copy()
df_Mae_disp = df_Mae_disp[df_Mae_disp['Unnamed: 8'] == 'DUPLICATE']
df_Mae_disp.head()
# Out:
#   Customer Return Date Customer Return Number  Product Code  \
# 4           2025-04-12                    NaN         30704
#
#    Product Description      UOM  Quantity Facility Counter Invoice Number  \
# 4  DYNAMITE CHOCO TWIN  SubCase         1     B.O.                    NaN
#
#   Unnamed: 8
# 4  DUPLICATE

# %%
df_Shaine.head()
# Out:
# Empty DataFrame
# Columns: [Customer Return Date, Customer Return Number, Product Code, Product Description, UOM, Quantity, Facility, Counter Invoice Number, Unnamed: 8]
# Index: []

# %%
import pandas as pd
import os
from openpyxl import load_workbook
from openpyxl.styles import Font, PatternFill, Alignment, NamedStyle
from openpyxl.utils import get_column_letter

import_01 = r"C:\Users\User\Downloads\COB DATA\2025\12.December\12.18.25\Requested GRN\DMS-GRN-on_01.xlsx"
import_02 = r"C:\Users\User\Downloads\COB DATA\2025\12.December\12.18.25\Requested GRN\DMS-GRN-on_02.xlsx"
import_03 = r"C:\Users\User\Downloads\COB DATA\2025\12.December\12.18.25\Requested GRN\DMS-GRN-on_03.xlsx"
import_04 = r"C:\Users\User\Downloads\COB DATA\2025\12.December\12.18.25\Requested GRN\DMS-GRN-on_04.xlsx"
import_05 = r"C:\Users\User\Downloads\COB DATA\2025\12.December\12.18.25\Requested GRN\DMS-GRN-on_05.xlsx"
import_06 = r"C:\Users\User\Downloads\COB DATA\2025\12.December\12.18.25\Requested GRN\DMS-GRN-on_06.xlsx"
import_07 = r"C:\Users\User\Downloads\COB DATA\2025\12.December\12.18.25\Requested GRN\DMS-GRN-on_07.xlsx"
import_08 = r"C:\Users\User\Downloads\COB DATA\2025\12.December\12.18.25\Requested GRN\DMS-GRN-on_08.xlsx"
import_09 = r"C:\Users\User\Downloads\COB DATA\2025\12.December\12.18.25\Requested GRN\DMS-GRN-on_09.xlsx"

df_01 = pd.read_excel(import_01)
df_01 = df_01[['Delivery Note/ Invoice/ ASN', 'GRN Status', 'GRN Confirmation Date']]
df_02 = pd.read_excel(import_02)
df_02 = df_02[['Delivery Note/ Invoice/ ASN', 'GRN Status', 'GRN Confirmation Date']]
df_03 = pd.read_excel(import_03)
df_03 = df_03[['Delivery Note/ Invoice/ ASN', 'GRN Status', 'GRN Confirmation Date']]
df_04 = pd.read_excel(import_04)
df_04 = df_04[['Delivery Note/ Invoice/ ASN', 'GRN Status', 'GRN Confirmation Date']]
df_05 = pd.read_excel(import_05)
df_05 = df_05[['Delivery Note/ Invoice/ ASN', 'GRN Status', 'GRN Confirmation Date']]
df_06 = pd.read_excel(import_06)
df_06 = df_06[['Delivery Note/ Invoice/ ASN', 'GRN Status', 'GRN Confirmation Date']]
df_07 = pd.read_excel(import_07)
df_07 = df_07[['Delivery Note/ Invoice/ ASN', 'GRN Status', 'GRN Confirmation Date']]
df_08 = pd.read_excel(import_08)
df_08 = df_08[['Delivery Note/ Invoice/ ASN', 'GRN Status', 'GRN Confirmation Date']]
df_09 = pd.read_excel(import_09)
df_09 = df_09[['Delivery Note/ Invoice/ ASN', 'GRN Status', 'GRN Confirmation Date']]
df_grn_combined = pd.concat([df_01, df_02, df_03, df_04, df_05, df_06, df_07, df_08, df_09], ignore_index=True)

export_path = r"C:\Users\User\Downloads\COB DATA\2025\12.December\12.18.25\Requested GRN\EXPORT"
export_GRN = os.path.join(export_path, "GRN_COMBINED.xlsx")
df_grn_combined.to_excel(export_GRN, index=False)
# Out:
# c:\Python313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Python313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Python313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Python313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
import pandas as pd
import os
from openpyxl import load_workbook
from openpyxl.styles import Font, PatternFill, Alignment, NamedStyle
from openpyxl.utils import get_column_letter
from datetime import datetime

date_str = "1.20.25"
date_obj = datetime.strptime(date_str, "%m.%d.%y")

year = date_obj.strftime("%Y")
month_name = date_obj.strftime("%m.%B")
month_check = date_obj.strftime("%m").lstrip('0')  # remove leading zeros
day_check = date_obj.strftime("%d").lstrip('0')    # remove leading zeros
year_check = date_obj.strftime("%Y")
day_folder = f"{month_check}.{day_check}.{year_check[2:]}"

base_dir = year + month_name + day_folder

print(base_dir)
# Out:
# 202501.January1.20.25

# %%
import pandas as pd
import os
from openpyxl import load_workbook
from openpyxl.styles import Font, PatternFill, Alignment, NamedStyle
from openpyxl.utils import get_column_letter


# Define paths
export_path = r"C:\Users\User\Downloads\COB DATA\2026\02.February\URC SUMMARY OF CLAIMS"
os.makedirs(export_path, exist_ok=True)

# Define import path
f01 = r"C:\Users\User\Downloads\COB DATA\2026\02.February\URC SUMMARY OF CLAIMS\01.xlsx"
f02 = r"C:\Users\User\Downloads\COB DATA\2026\02.February\URC SUMMARY OF CLAIMS\02.xlsx"
f03 = r"C:\Users\User\Downloads\COB DATA\2026\02.February\URC SUMMARY OF CLAIMS\03.xlsx"
f04 = r"C:\Users\User\Downloads\COB DATA\2026\02.February\URC SUMMARY OF CLAIMS\04.xlsx"
f05 = r"C:\Users\User\Downloads\COB DATA\2026\02.February\URC SUMMARY OF CLAIMS\05.xlsx"
f06 = r"C:\Users\User\Downloads\COB DATA\2026\02.February\URC SUMMARY OF CLAIMS\06.xlsx"
f07 = r"C:\Users\User\Downloads\COB DATA\2026\02.February\URC SUMMARY OF CLAIMS\07.xlsx"
f08 = r"C:\Users\User\Downloads\COB DATA\2026\02.February\URC SUMMARY OF CLAIMS\08.xlsx"
f09 = r"C:\Users\User\Downloads\COB DATA\2026\02.February\URC SUMMARY OF CLAIMS\09.xlsx"
# f10 = r"C:\Users\User\Downloads\COB DATA\2026\02.February\URC SUMMARY OF CLAIMS\10.xlsx"
# f11 = r"C:\Users\User\Downloads\COB DATA\2026\02.February\URC SUMMARY OF CLAIMS\11.xlsx"
# f12 = r"C:\Users\User\Downloads\COB DATA\2026\02.February\URC SUMMARY OF CLAIMS\12.xlsx"
# f13 = r"C:\Users\User\Downloads\COB DATA\2026\02.February\URC SUMMARY OF CLAIMS\13.xlsx"
# f14 = r"C:\Users\User\Downloads\COB DATA\2026\02.February\URC SUMMARY OF CLAIMS\14.xlsx"

# %%
# Load data from Excel files
df_01 = pd.read_excel(f01)
df_02 = pd.read_excel(f02)
df_03 = pd.read_excel(f03)
df_04 = pd.read_excel(f04)
df_05 = pd.read_excel(f05)
df_06 = pd.read_excel(f06)
df_07 = pd.read_excel(f07)
df_08 = pd.read_excel(f08)
df_09 = pd.read_excel(f09)
# df_10 = pd.read_excel(f10)
# df_11 = pd.read_excel(f11)
# df_12 = pd.read_excel(f12)
# df_13 = pd.read_excel(f13)
# df_14 = pd.read_excel(f14)

# Combine dataframes
df_combined = pd.concat([
     df_01 
    ,df_02 
    ,df_03 
    ,df_04 
    ,df_05 
    ,df_06 
    ,df_07 
    ,df_08 
    ,df_09 
    # ,df_10 
    # ,df_11 
    # ,df_12 
    # ,df_13 
    # ,df_14
    ], ignore_index=True)

df_combined.head()

# Export combined dataframe to Excel
export_file = os.path.join(export_path, "COMBINED.xlsx")
df_combined.to_excel(export_file, index=False)
# Out:
# c:\Python313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Python313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Python313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Python313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...
